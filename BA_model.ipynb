# %%
import requests
import gzip
import shutil
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("email-Eu-core.txt", header=None, names=["source", "target"])
print(df.head())
# Out:
#   source  target
# 0    0 1     NaN
# 1    2 3     NaN
# 2    2 4     NaN
# 3    5 6     NaN
# 4    5 7     NaN

# %%
import networkx as nx
import matplotlib.pyplot as plt

N = 1005
m = 10

BA_network = nx.barabasi_albert_graph(N, m)

plt.figure(figsize=(8, 6))
nx.draw(BA_network, node_size=10, edge_color="gray", alpha=0.7, with_labels=False)
plt.title("Barabási-Albert Model")
plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import networkx as nx

# # Generate Barabási-Albert (BA) network
# N = 1005  # Number of nodes
# m = 10    # Number of edges per new node
# BA_network = nx.barabasi_albert_graph(N, m)

# # Compute degree distribution
# degree_values = [d for _, d in BA_network.degree()]
# degree_counts = np.bincount(degree_values)

# # Plot degree distribution
# plt.figure(figsize=(8, 5))
# plt.loglog(range(len(degree_counts)), degree_counts, 'bo-', markersize=5)
# plt.xlabel("Degree (k)")
# plt.ylabel("Number of Nodes")
# plt.title("Degree Distribution")
# plt.grid(True, which="both", linestyle="--", alpha=0.6)
# plt.show()
import matplotlib.pyplot as plt
import seaborn as sns

# Compute degree sequence
degree_sequence = [d for n, d in BA_network.degree()]

# Plot histogram with KDE
plt.figure(figsize=(10, 6))
sns.histplot(degree_sequence, bins=30, kde=True, color="blue", alpha=0.5, edgecolor="black")

# Labels and title
plt.xlabel("Degree")
plt.ylabel("Frequency")
plt.title("Degree Distribution Barabási-Albert")

# Show plot
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Generate a layout for better visualization
pos = nx.spring_layout(ER_network, seed=42)

# Draw the network
plt.figure(figsize=(10, 6))
nx.draw(
    ER_network, pos,
    node_size=50,  # Small nodes for clarity
    node_color="blue",  # Color for nodes
    edge_color="gray",  # Light edges
    alpha=0.6,  # Transparency
    width=0.5  # Thin edges
)

# Title and display
plt.title("Erdős-Rényi Random Network Visualization")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d6eff90d3805> in <cell line: 0>()
#       3
#       4 # Generate a layout for better visualization
# ----> 5 pos = nx.spring_layout(ER_network, seed=42)
#       6
#       7 # Draw the network
#
# NameError: name 'ER_network' is not defined

# %%
# Compute clustering coefficients
clustering_values = list(nx.clustering(BA_network).values())

# Plot clustering coefficient distribution
plt.figure(figsize=(8, 5))
plt.hist(clustering_values, bins=30, color="skyblue", edgecolor="black", alpha=0.7)
plt.xlabel("Clustering Coefficient")
plt.ylabel("Number of Nodes")
plt.title("Clustering Coefficient Distribution Barabási-Albert")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
# Compute betweenness centrality
betweenness_values = list(nx.betweenness_centrality(BA_network).values())

# Plot betweenness centrality distribution
plt.figure(figsize=(8, 5))
plt.hist(betweenness_values, bins=30, color="lightcoral", edgecolor="black", alpha=0.7)
plt.xlabel("Betweenness Centrality")
plt.ylabel("Number of Nodes")
plt.title("Betweenness Centrality Distribution Barabási-Albert")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
# Find connected components sizes
component_sizes = [len(c) for c in nx.connected_components(BA_network)]

# Plot component size distribution
plt.figure(figsize=(8, 5))
plt.hist(component_sizes, bins=10, color="orange", edgecolor="black", alpha=0.7)
plt.xlabel("Component Size")
plt.ylabel("Number of Components")
plt.title("Connected Components Size Distribution Barabási-Albert")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
